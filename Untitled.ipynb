# %%
import numpy as np 
import pandas as pd
import matplotlib as plt

# %%
data=pd.read_csv('matches.csv')

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.tail(4)
# Out:
#       id  season       city        date                team1  \
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 632  normal           0  Royal Challengers Bangalore            0
# 633  normal           0          Sunrisers Hyderabad           22
# 634  normal           0          Sunrisers Hyderabad            0
# ...

# %%
data.shape #this will return a tuple which (rows , Columns ) of the data set..
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
a=data["winner"].head(9) # for fetching a column or a specific row and .head() is used additionally
print(a)
print("********************************************")
print(type(a))
# Out:
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# 5            Sunrisers Hyderabad
# 6                 Mumbai Indians
# 7                Kings XI Punjab
# 8               Delhi Daredevils
# Name: winner, dtype: object
# ********************************************
# <class 'pandas.core.series.Series'>

# %%
data[["team1", "team2", "winner"]].head(5)
# Out:
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               Mumbai Indians       Rising Pune Supergiant
# 2                Gujarat Lions        Kolkata Knight Riders
# 3       Rising Pune Supergiant              Kings XI Punjab
# 4  Royal Challengers Bangalore             Delhi Daredevils
#
#                         winner
# 0          Sunrisers Hyderabad
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4  Royal Challengers Bangalore

# %%
data.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.iloc[1:4] #data type of this will be data fraame because we are fetching multiple rows
# Out:
#    id  season    city        date                   team1  \
# 1   2    2017    Pune  2017-04-06          Mumbai Indians
# 2   3    2017  Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017  Indore  2017-04-08  Rising Pune Supergiant
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 2           0   Kolkata Knight Riders            0              10
# 3           0         Kings XI Punjab            0               6
#
#   player_of_match                                    venue         umpire1  \
# 1       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
print(data.iloc[1:,:2])
# Out:
#       id  season
# 1      2    2017
# 2      3    2017
# 3      4    2017
# 4      5    2017
# 5      6    2017
# ..   ...     ...
# 631  632    2016
# 632  633    2016
# 633  634    2016
# 634  635    2016
# 635  636    2016
#
# [635 rows x 2 columns]

# %%
# print(data.iloc[: , [2,3,8]]) #this is for specific rows and columns
print(data.iloc[ 0:10:2,  :])
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# 6               Mumbai Indians               Mumbai Indians         field
# 8       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
a.shape
data.head(4)
# Out:
#    id  season       city        date                   team1  \
# 0   1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# ...

# %%
mask=data['city']=='Hyderabad'
print(data[mask].shape)
# Out:
# (49, 18)

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
#funciton for finding number of matches played in a city by city name 
def search(city):
    mask=data['city']==city
    print(data[mask].shape[0])

search("Hyderabad")
# Out:
# 49

# %%
#caluculate frequencey of the coulumns and works only on catagorical data
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
data.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['win_by_runs'].value_counts()
# Out:
# win_by_runs
# 0      349
# 10       9
# 7        9
# 9        9
# 23       9
#       ...
# 62       1
# 138      1
# 71       1
# 144      1
# 80       1
# Name: count, Length: 86, dtype: int64

# %%
data['season'].value_counts().plot(kind='pie')
#pie works on numerical columns
# Out:
# <Axes: ylabel='count'>

# %%
data['toss_winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='toss_winner'>

# %%
data['toss_winner'].value_counts().head(7).plot(kind='barh')
# Out:
# <Axes: ylabel='toss_winner'>

# %%
data.sort_values('date' ,ascending=False )
# Out:
#     id  season        city        date                        team1  \
# 58  59    2017   Hyderabad  2017-05-21               Mumbai Indians
# 57  58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 56  57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 55  56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 54  55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# ..  ..     ...         ...         ...                          ...
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 60  61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# ...

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# creating groups in the dataset
cities=data.groupby('city')
print(cities)

# %%
#it give the number of rows in the dataset
len(data)
# Out:
# 636

# %%
#this will give the number of rows in the groups made
len(cities)
# Out:
# 30

# %%
# size() it give the number of matches playsed  in each city .. 
cities.size().sort_values(ascending=False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Cuttack            7
# Abu Dhabi          7
# Port Elizabeth     7
# Cape Town          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# dtype: int64

# %%
#give the first row of each group(city)
cities.first()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
#gives the last row(last match deatails) of each group(city)
cities.last()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       476    2014  2014-04-29             Rajasthan Royals
# Ahmedabad       540    2015  2015-04-24             Rajasthan Royals
# Bangalore       636    2016  2016-05-29          Sunrisers Hyderabad
# Bloemfontein    165    2009  2009-05-17             Delhi Daredevils
# Cape Town       130    2009  2009-04-26              Kings XI Punjab
# Centurion       172    2009  2009-05-22             Delhi Daredevils
# Chandigarh      622    2016  2016-05-15              Kings XI Punjab
# Chennai         563    2015  2015-05-10          Chennai Super Kings
# Cuttack         497    2014  2014-05-14               Mumbai Indians
# Delhi           635    2016  2016-05-27                Gujarat Lions
# Dharamsala      450    2013  2013-05-18              Kings XI Punjab
# Durban          169    2009  2009-05-20          Chennai Super Kings
# ...

# %%
cities.groups
# Out:
# {'Abu Dhabi': [457, 459, 460, 464, 470, 471, 475], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 333, 342, 346, 
# ...

# %%
data.iloc[456,:]
# Out:
# id                                   458
# season                              2014
# city                           Abu Dhabi
# date                          2014-04-16
# team1              Kolkata Knight Riders
# team2                     Mumbai Indians
# toss_winner        Kolkata Knight Riders
# toss_decision                        bat
# result                            normal
# dl_applied                             0
# winner             Kolkata Knight Riders
# win_by_runs                           41
# win_by_wickets                         0
# player_of_match                JH Kallis
# venue               Sheikh Zayed Stadium
# umpire1                        M Erasmus
# umpire2                   RK Illingworth
# umpire3                              NaN
# Name: 457, dtype: object

# %%
#will return the group of Ahmedabad means return the data of those matcheds which are played in ahmedabad
cities.get_group('Ahmedabad').shape
# Out:
# (12, 18)
