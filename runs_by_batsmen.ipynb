# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 4
#       2 import pandas as pd
#       3 import matplotlib as plt
# ----> 4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
data=pd.read_csv('deliveries.csv')

# %%
data.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data.shape
# Out:
# (150460, 21)

# %%
data.size
# Out:
# 3159660

# %%
group=data.groupby('batsman')

# %%
group['batsman_runs'].sum().sort_values(ascending=False).head(5)
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %%
#creating mask for the rows which has runs == 6 measn six hitted on a single delivery
mask=data['batsman_runs']==6
print(mask.dtype)
# Out:
# bool

# %%
#created new group for each batsmen with rows == 6
new_group=data[mask]
print(new_group.shape)
# Out:
# (6523, 21)

# %%
#for top six hitters
new_group.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head(5).reset_index()
# Out:
#      batsman  batsman_runs
# 0   CH Gayle           266
# 1   SK Raina           174
# 2  RG Sharma           173
# 3  DA Warner           160
# 4    V Kohli           160

# %%
player=data[data['batsman']=='DA Warner']

# %%
player.groupby('bowling_team')['batsman_runs'].sum().head(1)
# Out:
# bowling_team
# Chennai Super Kings    338
# Name: batsman_runs, dtype: int64

# %%
#if you have multiple data frames and your question is based on them and they are related so then you can merge them together 
#by using the merge function .. , left_on is  for the column name of the first dataframe and right_on is for the column in second df
# main=group.merge(new_group,left_on='match_id' , right_on='id')

# %%
delivery=pd.read_csv('deliveries.csv')

# %%
mask=delivery['batsman_runs']==6

# %%
delivery=delivery[mask]
delivery.pivot_table(index='over',columns='batting_team', values='batsman_runs', aggfunc='count')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15380\441863438.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   delivery=delivery[mask]
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# over
# 1                             5.0              3.0              14.0
# 2                            17.0             21.0              19.0
# 3                            37.0             11.0              30.0
# 4                            34.0             17.0              41.0
# 5                            41.0             27.0              29.0
# 6                            43.0             22.0              27.0
# 7                            22.0             11.0              20.0
# 8                            25.0             13.0              26.0
# 9                            23.0             17.0              32.0
# 10                           23.0             14.0              24.0
# ...
